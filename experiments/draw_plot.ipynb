# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

# Path to the folder containing the images
folder_path = 'no_roll_2024-11-09_16:14:09'

image_files = [f for f in os.listdir(folder_path) if f.endswith(('png', 'jpg', 'jpeg'))]

image_files = image_files[1:6]

fig, axes = plt.subplots(1, 5, figsize=(16, 15))

for i, img_file in enumerate(image_files):
    img = Image.open(os.path.join(folder_path, img_file))
    axes[i].imshow(img)
    axes[i].axis('off')  # Hide axis

plt.tight_layout()
plt.show()

# %%
folder_path = 'no_higher_2024-11-09_16:17:23'

image_files = [f for f in os.listdir(folder_path) if f.endswith(('png', 'jpg', 'jpeg'))]

image_files = image_files[1:6]

fig, axes = plt.subplots(1, 5, figsize=(11, 5))

for i, img_file in enumerate(image_files):
    img = Image.open(os.path.join(folder_path, img_file))
    axes[i].imshow(img)
    axes[i].axis('off')  # Hide axis

plt.tight_layout()
plt.show()
